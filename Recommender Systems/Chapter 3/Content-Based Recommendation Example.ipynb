# %% [markdown]
# ## Content-Based Recommendation Example

# %% [markdown]
# #### In this notebook, we will explore some approaches and techniques for content-based recommender systems. We will look at how to do text features extraction and represent items (in this case documents) as feature vectors. Then, we will see how we can obtain a feature-based representation of a user profile from user interactions with items, and generate a list of recommended items based on similarity (in terms of content features) to the user profile.

# %% [markdown]
# #### The data set we will use is from Deskdrop which is an internal communications platform developed by <a href="https://ciandt.com/us/en-us" target=_blank>CI&T</a>. Among other features, this platform allows companies employees to share relevant articles with their peers, and collaborate around them. The contains two files <a href="http://facweb.cs.depaul.edu/mobasher/classes/csc577/data/shared_articles.csv" target=_blank>"shared_articles.csv"</a> and <a href="http://facweb.cs.depaul.edu/mobasher/classes/csc577/data/users_interactions.csv" target=_blank>"users_interactions.csv"</a> containing, respectively, the shared documents and the log of user interactions with the items (such as viewing, liking, bookmarking, etc.). The original data set was provided by <a href="https://www.kaggle.com/gspmoreira/articles-sharing-reading-from-cit-deskdrop" target=_blank>Gabriel Moreira on Kaggle</a>.

# %%
import pandas as pd
import scipy as sp
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### We will use the following libraries for preprocessing tasks such as tokenization and vectorization of documents

# %%
import re
import nltk      ### Need to first install NLTK, e.g., "pip install nltk" or "conda install nltk" from conda
                 ### command prompt. Also see: https://www.nltk.org/install.html
nltk.download()  ### This will let you download various NLTK packages; it's only necessary to do this once

from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %% [markdown]
# #### The following function will read in a list of stop words to be used as part of tokenization of documents. You can obtain the file containing the stop words here: <a href="http://facweb.cs.depaul.edu/mobasher/classes/csc577/data/stopwords_en.txt" target=_blank>stopwords_en.txt</a>.

# %%
def get_stop_words():
    result = set()
    for line in open('stopwords_en.txt', 'r').readlines():
        result.add(line.strip())
    return result

# %%
stop_words = get_stop_words()

# %% [markdown]
# #### Load the articles and filter the document to keep only English documents. These will serve as our "items" for the purpose of recommendation.

# %%
articles_df = pd.read_csv('http://facweb.cs.depaul.edu/mobasher/classes/csc577/data/shared_articles.csv')
articles_df.head(3)
# Out:
#     timestamp        eventType            contentId       authorPersonId  \
# 0  1459192779  CONTENT REMOVED -6451309518266745024  4340306774493623681
# 1  1459193988   CONTENT SHARED -4110354420726924665  4340306774493623681
# 2  1459194146   CONTENT SHARED -7292285110016212249  4340306774493623681
#
#        authorSessionId authorUserAgent authorRegion authorCountry contentType  \
# 0  8940341205206233829             NaN          NaN           NaN        HTML
# 1  8940341205206233829             NaN          NaN           NaN        HTML
# 2  8940341205206233829             NaN          NaN           NaN        HTML
#
#                                                  url  \
# 0  http://www.nytimes.com/2016/03/28/business/dea...
# 1  http://www.nytimes.com/2016/03/28/business/dea...
# 2  http://cointelegraph.com/news/bitcoin-future-w...
#
#                                                title  \
# 0  Ethereum, a Virtual Currency, Enables Transact...
# 1  Ethereum, a Virtual Currency, Enables Transact...
# 2  Bitcoin Future: When GBPcoin of Branson Wins O...
#
#                                                 text lang
# 0  All of this work is still very early. The firs...   en
# 1  All of this work is still very early. The firs...   en
# 2  The alarm clock wakes me at 8:00 with stream o...   en

# %%
articles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3122 entries, 0 to 3121
# Data columns (total 13 columns):
# timestamp          3122 non-null int64
# eventType          3122 non-null object
# contentId          3122 non-null int64
# authorPersonId     3122 non-null int64
# authorSessionId    3122 non-null int64
# authorUserAgent    680 non-null object
# authorRegion       680 non-null object
# authorCountry      680 non-null object
# contentType        3122 non-null object
# url                3122 non-null object
# title              3122 non-null object
# text               3122 non-null object
# lang               3122 non-null object
# dtypes: int64(4), object(9)
# memory usage: 317.2+ KB

# %%
articles_df = articles_df[articles_df['eventType'] == 'CONTENT SHARED']
articles_df = articles_df[articles_df['lang'] == 'en']
articles_df.head(3)
# Out:
#     timestamp       eventType            contentId       authorPersonId  \
# 1  1459193988  CONTENT SHARED -4110354420726924665  4340306774493623681
# 2  1459194146  CONTENT SHARED -7292285110016212249  4340306774493623681
# 3  1459194474  CONTENT SHARED -6151852268067518688  3891637997717104548
#
#        authorSessionId authorUserAgent authorRegion authorCountry contentType  \
# 1  8940341205206233829             NaN          NaN           NaN        HTML
# 2  8940341205206233829             NaN          NaN           NaN        HTML
# 3 -1457532940883382585             NaN          NaN           NaN        HTML
#
#                                                  url  \
# 1  http://www.nytimes.com/2016/03/28/business/dea...
# 2  http://cointelegraph.com/news/bitcoin-future-w...
# 3  https://cloudplatform.googleblog.com/2016/03/G...
#
#                                                title  \
# 1  Ethereum, a Virtual Currency, Enables Transact...
# 2  Bitcoin Future: When GBPcoin of Branson Wins O...
# 3                       Google Data Center 360° Tour
#
#                                                 text lang
# 1  All of this work is still very early. The firs...   en
# 2  The alarm clock wakes me at 8:00 with stream o...   en
# 3  We're excited to share the Google Data Center ...   en

# %% [markdown]
# #### For the purpose of this example, we will only need the attributes "contentId", 'title', and 'text' (the latter attribute contains the text of the document).

# %%
articles = articles_df[['contentId', 'title', 'text']]
articles.head()
# Out:
#              contentId                                              title  \
# 1 -4110354420726924665  Ethereum, a Virtual Currency, Enables Transact...
# 2 -7292285110016212249  Bitcoin Future: When GBPcoin of Branson Wins O...
# 3 -6151852268067518688                       Google Data Center 360° Tour
# 4  2448026894306402386  IBM Wants to "Evolve the Internet" With Blockc...
# 5 -2826566343807132236  IEEE to Talk Blockchain at Cloud Computing Oxf...
#
#                                                 text
# 1  All of this work is still very early. The firs...
# 2  The alarm clock wakes me at 8:00 with stream o...
# 3  We're excited to share the Google Data Center ...
# 4  The Aite Group projects the blockchain market ...
# 5  One of the largest and oldest organizations fo...

# %%
articles.shape
# Out:
# (2211, 3)

# %%
### Reindex the articles dataframe to start from 0 (this is to avoid incosistencies when 
### we later use sparse matrices which use zero-based indexing)

articles.index = range(articles.shape[0])
articles.head()
# Out:
#              contentId                                              title  \
# 0 -4110354420726924665  Ethereum, a Virtual Currency, Enables Transact...
# 1 -7292285110016212249  Bitcoin Future: When GBPcoin of Branson Wins O...
# 2 -6151852268067518688                       Google Data Center 360° Tour
# 3  2448026894306402386  IBM Wants to "Evolve the Internet" With Blockc...
# 4 -2826566343807132236  IEEE to Talk Blockchain at Cloud Computing Oxf...
#
#                                                 text
# 0  All of this work is still very early. The firs...
# 1  The alarm clock wakes me at 8:00 with stream o...
# 2  We're excited to share the Google Data Center ...
# 3  The Aite Group projects the blockchain market ...
# 4  One of the largest and oldest organizations fo...

# %% [markdown]
# #### Next, we'll use scikit-learn's TfidfVectorizer to tokenize the documents and create as document-feature matrix. This fuction also performs the necessary transformation to convert the term weights into TFxIDF weights. The alternative is to use CountVectorizer which has similar capabilities, but results in simple term frequencies as weights. Please familiarize yourself with the documentation for these function to see various avaialble parameters. In this case, we'll see how the vectorizer function can tokenize (using the default tokenizer), remove stop words, and filter out terms that appear in more than 80% of the documents or in less than 3 documents. This will help in reducing the feature space. Note that this does not perform stemming. We will see a bit later how we can incorporate our own preprocessor that can perform additional tasks during tokenization, including stemming.

# %%
vectorizer = TfidfVectorizer(stop_words=stop_words, norm=None, max_df=0.8, min_df=3)

# %%
art_mat = vectorizer.fit_transform(articles['text'])

# %%
art_mat
# Out:
# <2211x17464 sparse matrix of type '<class 'numpy.float64'>'
# 	with 608391 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### This will produce a doucment-feature matrix in sparse matrix format. This is a sparse representation of a 2211x17464 document-feature matrix (documents are represented as 17464 feature vectors). Each entry here is in the form "(doc_id, term_id)  term_weight" and in this case, the term weights are TFxIDF values. Note that for the most part we will not need to convert this to a "dense" matrix with all the zeros present. Most Numpy, Scipy, and Scikit-learn functions that work with matrices, will work natively with sparse matrices. For example, below is the an example of accessing document vectors (rows in the document-term matrix) 0 through 99. Please review Scipy's documentation on sparse matrices: https://docs.scipy.org/doc/scipy/reference/sparse.html.

# %%
print(art_mat[0:100])
# Out:
#   (0, 1202)	2.6928391771996303
#   (0, 622)	3.3689335693768565
#   (0, 4599)	3.156474918162663
#   (0, 4474)	4.5119976206158
#   (0, 17405)	2.100422243913349
#   (0, 15)	2.413793802480441
#   (0, 9284)	2.5990937680286565
#   (0, 6470)	4.294933115377972
#   (0, 2745)	3.6264785474083983
#   (0, 13641)	7.092214450208125
#   (0, 12164)	2.796290514587655
#   (0, 2680)	6.6222108209623896
#   (0, 15740)	2.461376517471456
#   (0, 15277)	2.4711709150637438
#   (0, 2670)	4.624114918736506
#   (0, 12710)	2.2464537993021034
#   (0, 4087)	5.5235985322942796
#   (0, 4031)	6.062595033026967
#   (0, 15063)	4.20184269231196
#   (0, 14832)	4.731360449090104
#   (0, 13179)	4.574517977597134
#   (0, 13771)	3.2420668484980664
#   (0, 4410)	3.1761994235104414
#   (0, 16866)	6.757284767007635
#   (0, 15037)	6.504427785306006
#   :	:
#   (99, 9120)	5.949609230110056
#   (99, 5322)	16.361533668438923
#   (99, 6144)	2.875652255261775
#   (99, 14219)	3.4337942035788975
#   (99, 11444)	7.143715656043646
#   (99, 8119)	3.049163182373575
#   (99, 3435)	3.607902161835463
#   (99, 13171)	4.397587269438056
#   (99, 16028)	7.699244197445217
#   (99, 3457)	3.2723067336877847
#   (99, 2418)	2.1392082689485057
#   (99, 14527)	2.8494498828677512
#   (99, 16629)	1.4827426550231653
#   (99, 5241)	2.6757863888169107
#   (99, 9600)	1.5715538525166477
#   (99, 15741)	8.058175019102844
#   (99, 8451)	2.796290514587655
#   (99, 17317)	11.633537134262076
#   (99, 17048)	1.6132435839668307
#   (99, 5934)	4.542769279282553
#   (99, 17403)	2.1462954708315607
#   (99, 6962)	5.257215657083641
#   (99, 6125)	5.022673913578156
#   (99, 1971)	134.45896615398271
#   (99, 12386)	2.9427505887649446

# %% [markdown]
# #### Let's take a look at a subset of the terms/features extracted from the documents.

# %%
features = vectorizer.get_feature_names()
print(features[1000:1100])
# Out:
# ['amidst', 'amir', 'amis', 'amit', 'aml', 'amortized', 'amounts', 'amp', 'amphitheater', 'amphitheatre', 'ample', 'amplification', 'amplified', 'amplify', 'amplifying', 'amplitude', 'amps', 'amsterdam', 'amusement', 'amusing', 'amy', 'amzn', 'ana', 'anaconda', 'analog', 'analogies', 'analogous', 'analogue', 'analogy', 'analyse', 'analysed', 'analyser', 'analyses', 'analysing', 'analysis', 'analyst', 'analysts', 'analytic', 'analytical', 'analytics', 'analyze', 'analyzed', 'analyzer', 'analyzes', 'analyzing', 'ananthram', 'anathema', 'anatomy', 'ancestors', 'anchor', 'anchored', 'anchors', 'ancient', 'ancillary', 'anderson', 'andrea', 'andreas', 'andreessen', 'andrei', 'andrej', 'andrew', 'android', 'androidmanifest', 'andy', 'anecdotally', 'angel', 'angela', 'angeles', 'angellist', 'angels', 'anger', 'angered', 'angie', 'angle', 'angles', 'angry', 'angular', 'angular2', 'angularjs', 'ani', 'animal', 'animals', 'animate', 'animated', 'animates', 'animating', 'animation', 'animations', 'animator', 'anime', 'ann', 'anna', 'anne', 'annie', 'anniversary', 'annotate', 'annotated', 'annotating', 'annotation', 'annotations']

# %% [markdown]
# #### we can view the full vocabulary (a.k.a. dictionary) of features that are the dimensions for the vector represenation of items. This will also give us the total occurrence counts for each term across the whole collection of documents.

# %%
vectorizer.vocabulary_
# Out:
# {'work': 17291,
#  'early': 5228,
#  'public': 12386,
#  'version': 16791,
#  'ethereum': 5749,
#  'software': 14505,
#  'recently': 12754,
#  'released': 12997,
#  'face': 6043,
#  'technical': 15564,
#  'legal': 9176,
#  'problems': 12169,
#  'bitcoin': 1971,
#  'advocates': 752,
#  'say': 13719,
#  'security': 13878,
#  'greater': 7134,
#  'complexity': 3386,
#  'far': 6125,
#  'faced': 6046,
#  'testing': 15684,
#  'fewer': 6232,
#  'attacks': 1470,
#  'novel': 10686,
#  'design': 4533,
#  'invite': 8561,
#  'intense': 8395,
#  'scrutiny': 13829,
#  'authorities': 1545,
#  'given': 6962,
#  'potentially': 11926,
#  'fraudulent': 6626,
#  'contracts': 3699,
#  'like': 9280,
#  'ponzi': 11840,
#  'schemes': 13760,
#  'written': 17357,
#  'directly': 4744,
#  'sophisticated': 14548,
#  'capabilities': 2549,
#  'fascinating': 6138,
#  'executives': 5874,
#  'corporate': 3812,
#  'america': 992,
#  'ibm': 7809,
#  'said': 13645,
#  'year': 17403,
#  'experimenting': 5934,
#  'way': 17048,
#  'control': 3718,
#  'real': 12693,
#  'world': 17317,
#  'objects': 10755,
#  'called': 2502,
#  'internet': 8451,
#  'things': 15741,
#  'microsoft': 9986,
#  'working': 17302,
#  'projects': 12254,
#  'make': 9600,
#  'easier': 5241,
#  'use': 16629,
#  'computing': 3437,
#  'cloud': 3085,
#  'azure': 1631,
#  'general': 6860,
#  'platform': 11727,
#  'solve': 14530,
#  'industries': 8133,
#  'using': 16644,
#  'fairly': 6091,
#  'elegant': 5369,
#  'solution': 14527,
#  'seen': 13890,
#  'date': 4204,
#  'marley': 9714,
#  'gray': 7131,
#  'director': 4745,
#  'business': 2418,
#  'development': 4604,
#  'strategy': 14988,
#  'mr': 10315,
#  'responsible': 13259,
#  'blockchains': 2027,
#  'database': 4188,
#  'concept': 3457,
#  'introduced': 8504,
#  'designed': 4537,
#  'store': 14961,
#  'transactions': 16028,
#  'data': 4187,
#  'requiring': 13171,
#  'central': 2723,
#  'authority': 1546,
#  'repository': 13137,
#  'blockchain': 2026,
#  'ledgers': 9168,
#  'generally': 6868,
#  'maintained': 9591,
#  'updated': 16571,
#  'networks': 10535,
#  'computers': 3435,
#  'somewhat': 14539,
#  'similar': 14249,
#  'wikipedia': 17193,
#  'users': 16640,
#  'corporations': 3815,
#  'created': 3950,
#  'private': 12148,
#  'independent': 8091,
#  'ultimately': 16296,
#  'detract': 4591,
#  'value': 16705,
#  'individual': 8119,
#  'unit': 16453,
#  'known': 8967,
#  'ether': 5748,
#  'people': 11444,
#  'buying': 2437,
#  'sign': 14219,
#  'fascination': 6139,
#  'major': 9597,
#  'banks': 1714,
#  'expressed': 5989,
#  'trading': 15999,
#  'money': 10212,
#  'transfer': 16036,
#  'faster': 6144,
#  'efficient': 5322,
#  'tuesday': 16199,
#  'largest': 9050,
#  'gather': 6823,
#  'conference': 3504,
#  'tapping': 15510,
#  'potential': 11925,
#  'cutting': 4117,
#  'hype': 7784,
#  'looking': 9441,
#  'jpmorgan': 8798,
#  'instance': 8325,
#  'specific': 14629,
#  'tool': 15912,
#  'allows': 938,
#  'internal': 8443,
#  'databases': 4189,
#  'interact': 8409,
#  'michael': 9970,
#  'executive': 5873,
#  'equity': 5680,
#  'firm': 6337,
#  'fortress': 6568,
#  'investing': 8551,
#  'group': 7183,
#  'helped': 7480,
#  'lead': 9120,
#  'investment': 8552,
#  'left': 9172,
#  'fall': 6098,
#  'significant': 14230,
#  'purchase': 12422,
#  'january': 8691,
#  'heard': 7444,
#  'financial': 6300,
#  'industry': 8134,
#  'chatter': 2834,
#  'virtual': 16851,
#  'currency': 4088,
#  'evolved': 5804,
#  'lot': 9466,
#  'established': 5731,
#  'players': 11737,
#  'thinking': 15745,
#  'experiment': 5930,
#  'feels': 6206,
#  'months': 10237,
#  'getting': 6928,
#  'validation': 16696,
#  'beginning': 1819,
#  'soared': 14478,
#  'high': 7525,
#  '12': 51,
#  'brought': 2313,
#  'existing': 5896,
#  'billion': 1936,
#  'times': 15845,
#  'significantly': 14231,
#  'outstanding': 11093,
#  'week': 17101,
#  'invented': 8532,
#  'alt': 951,
#  'coins': 3182,
#  'tried': 16135,
#  'improve': 8003,
#  'won': 17269,
#  'following': 6475,
#  'unlike': 16473,
#  '2009': 209,
#  'mysterious': 10391,
#  'creator': 3959,
#  'satoshi': 13702,
#  'nakamoto': 10409,
#  'transparent': 16075,
#  'fashion': 6140,
#  '21': 236,
#  'old': 10852,
#  'russian': 13614,
#  'canadian': 2529,
#  'vitalik': 16885,
#  'buterin': 2426,
#  'dropped': 5142,
#  'waterloo': 17035,
#  'university': 16462,
#  'ontario': 10889,
#  'basic': 1754,
#  'aim': 838,
#  'possible': 11904,
#  'program': 12224,
#  'binding': 1946,
#  'agreements': 824,
#  'smart': 14419,
#  'contract': 3695,
#  'bet': 1897,
#  'sports': 14710,
#  'game': 6783,
#  'final': 6290,
#  'score': 13784,
#  'came': 2513,
#  'mutually': 10382,
#  'agreed': 821,
#  'source': 14570,
#  'associated': 1406,
#  'press': 12069,
#  'automatically': 1567,
#  'transferred': 16037,
#  'winning': 17226,
#  'party': 11323,
#  'used': 16631,
#  'necessary': 10480,
#  'pay': 11379,
#  'network': 10532,
#  'power': 11935,
#  'needed': 10487,
#  'process': 12178,
#  'described': 4522,
#  'single': 14284,
#  'shared': 14071,
#  'computer': 3433,
#  'run': 13596,
#  'resources': 13236,
#  'paid': 11205,
#  'team': 15546,
#  'seven': 14024,
#  'founders': 6589,
#  'write': 17351,
#  'initial': 8226,
#  'description': 4525,
#  'raised': 12596,
#  '18': 120,
#  'million': 10030,
#  '2014': 217,
#  'fund': 6730,
#  'foundation': 6584,
#  'supports': 15271,
#  'succeeded': 15155,
#  'attracting': 1493,
#  'dedicated': 4325,
#  'followers': 6474,
#  'support': 15265,
#  'partly': 11315,
#  'hope': 7649,
#  'increase': 8066,
#  'succeeds': 15157,
#  '800': 412,
#  'nodes': 10611,
#  'helping': 7484,
#  '400': 316,
#  'joseph': 8779,
#  'lubin': 9503,
#  'set': 14008,
#  'consensys': 3571,
#  'company': 3320,
#  'based': 1747,
#  'brooklyn': 2308,
#  'hired': 7561,
#  '50': 341,
#  'developers': 4602,
#  'build': 2359,
#  'applications': 1203,
#  'including': 8038,
#  'enables': 5490,
#  'music': 10365,
#  'distribution': 4923,
#  'new': 10544,
#  'kind': 8928,
#  'auditing': 1515,
#  'offices': 10830,
#  'industrial': 8131,
#  'building': 2362,
#  'section': 13869,
#  'office': 10827,
#  'essentially': 5727,
#  'large': 9047,
#  'room': 13525,
#  'messy': 9935,
#  'trademarks': 15993,
#  'start': 14845,
#  'operation': 10921,
#  'white': 17160,
#  'boards': 2069,
#  'walls': 16972,
#  'parts': 11322,
#  'lying': 9531,
#  'thrown': 15795,
#  'starting': 14849,
#  'think': 15742,
#  'delivered': 4413,
#  'failed': 6082,
#  'promise': 12265,
#  'especially': 5720,
#  'allowing': 937,
#  'kinds': 8932,
#  'online': 10881,
#  'markets': 9707,
#  'presented': 12055,
#  'broad': 2289,
#  'strokes': 15037,
#  'vision': 16866,
#  'deliver': 4410,
#  'science': 13771,
#  'researcher': 13179,
#  'stanford': 14832,
#  'studies': 15063,
#  'crypto': 4031,
#  'currencies': 4087,
#  'really': 12710,
#  'caught': 2670,
#  'sure': 15277,
#  'thing': 15740,
#  'cautioned': 2680,
#  'probably': 12164,
#  'safest': 13641,
#  'certainly': 2745,
#  'folks': 6470,
#  'likely': 9284,
#  '10': 15,
#  'years': 17405,
#  'depend': 4474,
#  'develop': 4599,
#  'actual': 622,
#  'application': 1202,
#  'alarm': 866,
#  'clock': 3065,
#  'wakes': 16955,
#  '00': 0,
#  'stream': 14993,
#  'advert': 729,
#  'free': 6633,
#  'broadcasting': 2293,
#  'charged': 2805,
#  'second': 13859,
#  'current': 4089,
#  'btc': 2336,
#  'exchange': 5843,
#  'rate': 12642,
#  'makes': 9605,
#  'button': 2432,
#  'costly': 3850,
#  'proposition': 12313,
#  'coffee': 3157,
#  'check': 2845,
#  'overnight': 11133,
#  'performance': 11470,
#  'bots': 2167,
#  'earns': 5235,
#  'trump': 16177,
#  'allocates': 929,
#  'funds': 6738,
#  'main': 9580,
#  'chain': 2758,
#  'various': 16732,
#  'national': 10444,
#  'chains': 2761,
#  'generated': 6871,
#  'lucrative': 9508,
#  '24': 249,
#  'return': 13330,
#  'reliably': 13008,
#  'profitable': 12219,
#  'trade': 15990,
#  'according': 550,
#  'political': 11818,
#  'prediction': 11992,
#  'market': 9700,
#  'expected': 5912,
#  'latest': 9070,
#  'poll': 11822,
#  'numbers': 10718,
#  'highly': 7533,
#  'supportive': 15270,
#  'election': 5357,
#  'ceo': 2739,
#  'resistance': 13217,
#  'anonymizing': 1117,
#  'spending': 14664,
#  'moving': 10308,
#  'confidential': 3510,
#  'layer': 9102,
#  'continues': 3689,
#  'erode': 5697,
#  'coin': 3175,
#  'credibility': 3965,
#  'speech': 14650,
#  'maintains': 9595,
#  'ct': 4044,
#  'privacy': 12147,
#  'essential': 5726,
#  'sinister': 14289,
#  'ring': 13439,
#  'signature': 14226,
#  'note': 10658,
#  'long': 9431,
#  'position': 11890,
#  'memo': 9882,
#  'effect': 5314,
#  'government': 7058,
#  'finances': 6299,
#  'compliance': 3387,
#  'british': 2286,
#  'corruption': 3839,
#  'light': 9270,
#  'britain': 2285,
#  'leads': 9127,
#  'global': 6982,
#  'recovery': 12804,
#  'great': 7133,
#  'debt': 4252,
#  'default': 4344,
#  '20': 197,
#  'happy': 7343,
#  'project': 12248,
#  'performing': 11476,
#  'line': 9301,
#  'expectations': 5911,
#  'serves': 14000,
#  'autonomous': 1574,
#  'info': 8183,
#  'agent': 800,
#  'contracting': 3696,
#  'ais': 855,
#  'providers': 12356,
#  'bounty': 2184,
#  'awarded': 1610,
#  'outfit': 11057,
#  'mountain': 10288,
#  'motion': 10268,
#  'sensing': 13949,
#  'rigs': 13438,
#  'repaid': 13094,
#  'figures': 6264,
#  'best': 1892,
#  'provides': 12357,
#  'valuable': 16702,
#  'artificial': 1331,
#  'intelligence': 8386,
#  'charge': 2804,
#  'swiss': 15380,
#  'military': 10021,
#  'robotics': 13488,
#  'll': 9373,
#  'soon': 14546,
#  'retire': 13308,
#  'city': 2976,
#  'mars': 9722,
#  'excited': 5848,
#  'share': 14069,
#  'google': 7037,
#  'center': 2717,
#  '360': 298,
#  'tour': 15957,
#  'youtube': 17429,
#  'video': 16817,
#  'gives': 6963,
#  'unprecedented': 16502,
#  'immersive': 7931,
#  'look': 9439,
#  'inside': 8288,
#  'centers': 2721,
#  'ways': 17050,
#  'view': 16820,
#  'desktop': 4548,
#  'chrome': 2925,
#  'mouse': 10293,
#  'trackpad': 15986,
#  'change': 2783,
#  'plays': 11743,
#  'app': 1173,
#  'mobile': 10144,
#  'device': 4610,
#  'angles': 1074,
#  'cardboard': 2590,
#  'currently': 4090,
#  'supported': 15266,
#  'android': 1061,
#  'ios': 8584,
#  'coming': 3263,
#  'load': 9375,
#  'tap': 15506,
#  'icon': 7815,
#  'starts': 14850,
#  'play': 11731,
#  'insert': 8283,
#  'phone': 11587,
#  'little': 9362,
#  'background': 1646,
#  'ago': 819,
#  'developer': 4601,
#  'advocacy': 749,
#  'rare': 12637,
#  'opportunity': 10933,
#  'oregon': 10988,
#  'non': 10622,
#  'careers': 2596,
#  'experience': 5925,
#  'imagined': 7908,
#  'blown': 2049,
#  'away': 1615,
#  'scale': 13727,
#  'incredible': 8071,
#  'attention': 1486,
#  'amazing': 973,
#  'efforts': 5327,
#  'extremely': 6027,
#  'green': 7142,
#  'additionally': 656,
#  'proud': 12343,
#  'meet': 9855,
#  'brilliant': 2277,
#  'maintain': 9588,
#  'customer': 4104,
#  'want': 16983,
#  'experienced': 5926,
#  'enjoy': 5574,
#  'posted': 11910,
#  'greg': 7151,
#  'wilson': 17208,
#  'head': 7412,
#  'valued': 16706,
#  '2019': 222,
#  'reason': 12719,
#  'biggest': 1926,
#  'names': 10412,
#  'banking': 1712,
#  'technology': 15576,
#  'entered': 5605,
#  'space': 14581,
#  'evaluate': 5770,
#  'linux': 9326,
#  'brightest': 2273,
#  'minds': 10045,
#  'hyperledger': 7788,
#  'umbrella': 16298,
#  'seeks': 13888,
#  'incorporate': 8059,
#  'findings': 6306,
#  'blockstream': 2032,
#  'ripple': 13447,
#  'digital': 4698,
#  'asset': 1388,
#  'holdings': 7595,
#  'order': 10979,
#  'useful': 16632,
#  'contributed': 3711,
#  'code': 3140,
#  'john': 8756,
#  'offering': 10824,
#  'began': 1814,
#  'clear': 3031,
#  'wanted': 16984,
#  'disrupt': 4878,
#  'disruption': 4881,
#  'gathered': 6824,
#  'exploring': 5970,
#  'announced': 1101,
#  'december': 4270,
#  '17': 109,
#  '2015': 218,
#  'just': 8843,
#  'day': 4217,
#  'later': 9069,
#  '300': 280,
#  'companies': 3318,
#  'requested': 13163,
#  'join': 8760,
#  'open': 10899,
#  'history': 7571,
#  '450': 328,
#  'inquiries': 8270,
#  'going': 7015,
#  'holy': 7615,
#  'mess': 9927,
#  'san': 13673,
#  'francisco': 6617,
#  'lighthouse': 9272,
#  'partners': 11319,
#  'puts': 12452,
#  'quest': 12516,
#  'understand': 16370,
#  'important': 7978,
#  'don': 5019,
#  'know': 8961,
#  'got': 7047,
#  'rap': 12633,
#  '70s': 397,
#  'cool': 3770,
#  'founded': 6587,
#  'taxi': 15531,
#  'service': 14001,
#  'explained': 5946,
#  'original': 11015,
#  'crazy': 3946,
#  'guys': 7246,
#  '60s': 377,
#  'imagine': 7907,
#  'doing': 4999,
#  'wild': 17194,
#  'eyed': 6034,
#  'image': 7897,
#  'quantum': 12498,
#  'semantic': 13923,
#  'chips': 2895,
#  'count': 3861,
#  'stuff': 15068,
#  'does': 4992,
#  'says': 13721,
#  'approaches': 1221,
#  'spirit': 14683,
#  'innovation': 8262,
#  'method': 9951,
#  'operations': 10924,
#  'mo': 10143,
#  '1990s': 176,
#  'cites': 2968,
#  'java': 8701,
#  'today': 15881,
#  'weren': 17134,
#  'pretty': 12086,
#  'young': 17425,
#  'dude': 5175,
#  'dollar': 5003,
#  'decision': 4284,
#  'xml': 17382,
#  'example': 5821,
#  'dedication': 4328,
#  'employees': 5468,
#  'distributed': 4920,
#  'systems': 15434,
#  'consensus': 3570,
#  'algorithms': 893,
#  'entire': 5621,
#  '30': 279,
#  'planetary': 11711,
#  've': 16742,
#  'gone': 7026,
#  'couple': 3882,
#  'approaching': 1222,
#  'army': 1299,
#  'job': 8748,
#  'making': 9607,
#  'led': 9165,
#  'friends': 6669,
#  'contact': 3646,
#  'multinational': 10337,
#  'consulting': 3636,
#  'corporation': 3814,
#  'calling': 2504,
#  'constantly': 3607,
#  'saying': 13720,
#  'hey': 7507,
#  'let': 9212,
#  'learning': 9148,
#  'started': 14846,
#  'accelerate': 509,
#  'went': 17133,
#  'evolving': 5806,
#  'problem': 12167,
#  'need': 10486,
#  'environments': 5649,
#  'trust': 16182,
#  'agree': 820,
#  'end': 5521,
#  'era': 5683,
#  'manages': 9630,
#  'gets': 6926,
#  'compensated': 3340,
#  'risk': 13454,
#  'finance': 6297,
#  'consumers': 3642,
#  'institutions': 8343,
#  'handle': 7308,
#  'complete': 3377,
#  'protocol': 12338,
#  'centralized': 2728,
#  'movement': 10299,
#  'doesn': 4993,
#  'follow': 6471,
#  'having': 7397,
#  'false': 6105,
#  'dichotomy': 4655,
#  'notion': 10677,
#  'walled': 16968,
#  'garden': 6801,
#  'compare': 3326,
#  'wrong': 17358,
#  'analogy': 1028,
#  'apt': 1239,
#  'perspective': 11534,
#  'permissioned': 11494,
#  'permissive': 11498,
#  'iteration': 8654,
#  'time': 15833,
#  'told': 15892,
#  'audience': 1507,
#  'thinks': 15746,
#  'evolve': 5803,
#  'constrained': 3617,
#  'fabric': 6040,
#  'lots': 9467,
#  'competition': 3352,
#  'platforms': 11728,
#  'huge': 7734,
#  'amounts': 1006,
#  'solutions': 14528,
#  'economically': 5272,
#  'aware': 1612,
#  'isn': 8625,
#  'mean': 9817,
#  'technologies': 15573,
#  'lost': 9465,
#  'causes': 2676,
#  'completely': 3379,
#  'retool': 13312,
#  'fact': 6062,
#  'works': 17310,
#  'focused': 6458,
#  'cryptocurrency': 4033,
#  'radically': 12577,
#  'bankers': 1711,
#  'gonna': 7027,
#  'try': 16189,
#  'heck': 7463,
#  'ahead': 830,
#  'overstock': 11149,
#  't0': 15436,
#  'happening': 7337,
#  'happen': 7335,
#  'plenty': 11754,
#  'commit': 3285,
#  'woken': 17265,
#  'disrupting': 4880,
#  'maybe': 9801,
#  'wonders': 17276,
#  'aloud': 943,
#  'itunes': 8661,
#  'napster': 10426,
#  'netflix': 10528,
#  'bittorrent': 1979,
#  'products': 12201,
#  'watson': 17041,
#  'ecosystem': 5279,
#  'giant': 6934,
#  'investigating': 8547,
#  'details': 4570,
#  'oftentimes': 10842,
#  'innovations': 8263,
#  'ready': 12691,
#  'route': 13553,
#  'taken': 15476,
#  'par': 11253,
#  'ireland': 8604,
#  'energy': 5545,
#  'consumption': 3645,
#  'mining': 10070,
#  'eventually': 5787,
#  'dictate': 4657,
#  'dealing': 4237,
#  'identify': 7836,
#  'spread': 14721,
#  'arab': 1244,
#  'spring': 14727,
#  'role': 13504,
#  'played': 11735,
#  'structure': 15048,
#  'functions': 6729,
#  'websites': 17093,
#  'albeit': 872,
#  'remained': 13033,
#  'unruly': 16525,
#  'warned': 17001,
#  'movie': 10306,
#  'startups': 14852,
#  'equally': 5667,
#  'good': 7028,
#  'shot': 14163,
#  'maintaining': 9594,
#  'keeping': 8874,
#  'scoped': 13781,
#  'simple': 14254,
#  'oldest': 10854,
#  'organizations': 11004,
#  'professionals': 12206,
#  'kick': 8907,
#  'annual': 1110,
#  'future': 6755,
#  'tomorrow': 15902,
#  'scheduled': 13752,
#  'attractions': 1495,
#  '000': 1,
#  'members': 9874,
#  '260': 262,
#  'countries': 3876,
#  'institute': 8339,
#  'electrical': 5360,
#  'electronics': 5366,
#  'engineers': 5563,
#  'ieee': 7851,
#  'holding': 7594,
#  'profile': 12212,
#  'event': 5784,
#  'adoption': 704,
#  'engineering': 5562,
#  'community': 3313,
#  'host': 7677,
#  'seminars': 13932,
#  '702': 396,
#  'college': 3217,
#  'oxford': 11171,
#  '2016': 219,
#  'organization': 11002,
#  'fourth': 6594,
#  'services': 14003,
#  'speaking': 14611,
#  'hosted': 7678,
#  'professor': 12208,
#  'wei': 17108,
#  'school': 13767,
#  'arizona': 1288,
#  'state': 14858,
#  'talk': 15488,
#  'academic': 505,
#  'topic': 15924,
#  'research': 13177,
#  'shift': 14109,
#  'looks': 9443,
#  'deal': 4234,
#  'closely': 3074,
#  'presence': 12050,
#  'surprise': 15295,
#  'shaping': 14065,
#  'stopped': 14956,
#  'talking': 15490,
#  'decentralized': 4274,
#  'ledger': 9167,
#  'month': 10235,
#  'splash': 14688,
#  'wide': 17178,
#  'range': 12620,
#  'news': 10553,
#  'related': 12977,
#  'initiatives': 8239,
#  'november': 10689,
#  'coined': 3181,
#  'term': 15648,
#  'baas': 1635,
#  'sandbox': 13675,
#  'environment': 5646,
#  'tools': 15920,
#  'augur': 1524,
#  'slock': 14397,
#  'joined': 8761,
#  'effort': 5324,
#  'shutterstock': 14194,
#  'come': 3254,
#  'idea': 7821,
#  'embracing': 5426,
#  'fintech': 6326,
#  'innovate': 8260,
#  'accelerated': 510,
#  'pace': 11182,
#  'unable': 16299,
#  'bank': 1709,
#  'api': 1162,
#  'access': 525,
#  'step': 14905,
#  'right': 13432,
#  'direction': 4739,
#  'input': 8268,
#  'liking': 9288,
#  'competitors': 3358,
#  'offerings': 10825,
#  'true': 16174,
#  'bring': 2280,
#  'improvements': 8006,
#  'table': 15441,
#  'complementary': 3373,
#  'allies': 924,
#  'success': 15158,
#  'monetary': 10208,
#  'singapore': 14280,
#  'read': 12679,
#  'price': 12104,
#  'analysis': 1034,
#  '03': 5,
#  '28': 265,
#  'buy': 2434,
#  'denying': 4467,
#  'sector': 13871,
#  'quite': 12544,
#  'opening': 10906,
#  'door': 5033,
#  'offer': 10822,
#  'entirely': 5622,
#  'different': 4677,
#  'experts': 5939,
#  'threats': 15778,
#  'explain': 5945,
#  'vocal': 16898,
#  'opposition': 10936,
#  'controlled': 3719,
#  'sees': 13891,
#  'feel': 6203,
#  'capable': 2551,
#  'complementing': 3374,
#  'infrastructure': 8197,
#  'competing': 3351,
#  'combination': 3244,
#  'traditional': 16001,
#  'innovative': 8264,
#  'create': 3949,
#  'powerful': 11937,
#  'versatile': 16787,
#  'globe': 6988,
#  'entrepreneurs': 5633,
#  'renowned': 13081,
#  'outside': 11086,
#  'proverbial': 12350,
#  'box': 2189,
#  'comes': 3257,
#  'accessing': 530,
#  'particularly': 11309,
#  'lending': 9196,
#  'peer': 11421,
#  'aspect': 1358,
#  'concerned': 3464,
#  'leg': 9174,
#  'counterparts': 3868,
#  'able': 473,
#  'slow': 14406,
#  'simply': 14264,
#  'unwilling': 16563,
#  'collaborating': 3193,
#  'preferable': 12005,
#  'alternative': 959,
#  'involve': 8574,
#  'pride': 12110,
#  'advanced': 713,
#  'technological': 15571,
#  'features': 6188,
#  'invaluable': 8525,
#  'senior': 13940,
#  'regulator': 12943,
#  'stated': 14859,
#  'approach': 1218,
#  'help': 7479,
#  'succeed': 15154,
#  'disruptors': 4885,
#  'versus': 16795,
#  'enablers': 5489,
#  'enabler': 5488,
#  'creating': 3952,
#  'superior': 15241,
#  'lies': 9254,
#  'partnering': 11318,
#  'enabling': 5491,
#  'governments': 7060,
#  'despite': 4555,
#  'barriers': 1738,
#  'popular': 11853,
#  'available': 1585,
#  'country': 3877,
#  'frictionless': 6658,
#  'transfers': 16039,
#  'regardless': 12915,
#  'previous': 12101,
#  'businesses': 2419,
#  'taking': 15480,
#  'page': 11200,
#  'playbook': 11733,
#  'trying': 16190,
#  'considering': 3585,
#  'issue': 8635,
#  ...}

# %% [markdown]
# #### You might note, however that without stemming, we have many redundant variants of terms as features. For example, 'animate', 'animated', 'animates', 'animating', 'animation', 'animations' are all considered distinct features. This not only increases the size of the feature space, but will potentially prevent matches among pairs of documents that don't include the same variants of terms. So, we need to include stemming as part of our preprocessing. To do this with the vectroizer functions in Scikit-learn, we will need to create our own preprocessing function that performs tokenization, stemming, and other normalization tasks on a given document and returns the transformed document (to be used by TfidfVectorizer). In this case, we will employ NLTK's facilities for tokenization, stemming and stop word handling as part of our "normalize_document" function.

# %%
def normalize_document(doc):
    wpt = nltk.WordPunctTokenizer()
    stop_words = nltk.corpus.stopwords.words('english')
    ps = nltk.stem.PorterStemmer()
    # convert to lower case, and remove special characters and white space
    doc = re.sub(r'[^a-zA-Z0-9_\s]', '', doc, re.I)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize the document
    tokens = wpt.tokenize(doc)
    # remove stopwords
    filtered_tokens = [token for token in tokens if (token not in stop_words and token not in ["."])]
    # put the filtered document back together
    doc = ' '.join([ps.stem(token) for token in filtered_tokens])
    return doc

# %% [markdown]
# #### Lets' call the vectorizer function again, but use our "normalize_document" function as the preprocessor. (Note, however, that this could be significantly slower than the previous version.)

# %%
vectorizer2 = TfidfVectorizer(preprocessor=normalize_document, norm=None, max_df=0.8, min_df=3)

# %%
vectorizer2.fit(articles['text'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.8, max_features=None,
#                 min_df=3, ngram_range=(1, 1), norm=None,
#                 preprocessor=<function normalize_document at 0x000001D841A76DC8>,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
art_mat2 = vectorizer2.transform(articles['text'])

# %%
art_mat2
# Out:
# <2211x11194 sparse matrix of type '<class 'numpy.float64'>'
# 	with 579559 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### Note that the feature space is not significantly smaller and the features are not stemmed versions of the original terms.

# %%
features2 = vectorizer2.get_feature_names()
print(features2[1000:1100])
# Out:
# ['atap', 'atari', 'ate', 'athlet', 'atla', 'atlant', 'atlanta', 'atlassian', 'atm', 'atmospher', 'atom', 'atop', 'attach', 'attack', 'attain', 'attempt', 'attend', 'attende', 'attent', 'attest', 'attia', 'attitud', 'attract', 'attribut', 'attrit', 'auction', 'audac', 'audibl', 'audienc', 'audio', 'audiobook', 'audiophil', 'audit', 'auditor', 'auditori', 'augment', 'augur', 'august', 'aunt', 'aura', 'aurora', 'auster', 'austin', 'australia', 'australian', 'austria', 'auth', 'auth0', 'authent', 'author', 'authoris', 'authorit', 'authorship', 'autist', 'auto', 'autocomplet', 'autocorrect', 'autodesk', 'autofocu', 'autom', 'automag', 'automak', 'automat', 'automl', 'automobil', 'automot', 'autonom', 'autonomi', 'autopilot', 'autosc', 'autoscal', 'autovalu', 'autowir', 'auxiliari', 'av', 'avail', 'avatar', 'avenu', 'averag', 'avers', 'avg', 'aviat', 'avid', 'aviv', 'avoid', 'avro', 'aw', 'await', 'awak', 'awaken', 'awar', 'award', 'awash', 'away', 'awe', 'awesom', 'awhil', 'awk', 'awkward', 'awri']

# %%
vectorizer2.vocabulary_
# Out:
# {'work': 11047,
#  'still': 9443,
#  'earli': 3281,
#  'first': 3915,
#  'full': 4165,
#  'public': 7853,
#  'version': 10681,
#  'ethereum': 3587,
#  'softwar': 9167,
#  'recent': 8103,
#  'releas': 8231,
#  'system': 9747,
#  'could': 2453,
#  'face': 3737,
#  'technic': 9835,
#  'legal': 5790,
#  'problem': 7751,
#  'tarnish': 9803,
#  'bitcoin': 1345,
#  'mani': 6097,
#  'advoc': 589,
#  'say': 8652,
#  'secur': 8746,
#  'greater': 4463,
#  'complex': 2250,
#  'thu': 10003,
#  'far': 3784,
#  'much': 6552,
#  'less': 5814,
#  'test': 9909,
#  'fewer': 3854,
#  'attack': 1013,
#  'novel': 6836,
#  'design': 2872,
#  'may': 6197,
#  'also': 717,
#  'invit': 5329,
#  'intens': 5255,
#  'scrutini': 8718,
#  'author': 1049,
#  'given': 4333,
#  'potenti': 7619,
#  'fraudul': 4104,
#  'contract': 2378,
#  'like': 5860,
#  'ponzi': 7578,
#  'scheme': 8676,
#  'written': 11091,
#  'directli': 2977,
#  'sophist': 9204,
#  'capabl': 1745,
#  'made': 6044,
#  'fascin': 3790,
#  'execut': 3660,
#  'corpor': 2432,
#  'america': 747,
#  'ibm': 4954,
#  'said': 8595,
#  'last': 5713,
#  'year': 11138,
#  'experi': 3680,
#  'way': 10861,
#  'control': 2389,
#  'real': 8063,
#  'world': 11061,
#  'object': 6885,
#  'call': 1705,
#  'internet': 5278,
#  'thing': 9962,
#  'microsoft': 6327,
#  'sever': 8837,
#  'project': 7784,
#  'make': 6072,
#  'easier': 3291,
#  'use': 10579,
#  'comput': 2266,
#  'cloud': 2084,
#  'azur': 1105,
#  'gener': 4266,
#  'platform': 7500,
#  'solv': 9185,
#  'industri': 5133,
#  'fairli': 3760,
#  'eleg': 3371,
#  'solut': 9184,
#  'seen': 8758,
#  'date': 2699,
#  'marley': 6142,
#  'gray': 4459,
#  'director': 2978,
#  'busi': 1649,
#  'develop': 2903,
#  'strategi': 9481,
#  'mr': 6544,
#  'respons': 8348,
#  'blockchain': 1385,
#  'databas': 2687,
#  'concept': 2276,
#  'introduc': 5306,
#  'store': 9465,
#  'transact': 10153,
#  'data': 2686,
#  'without': 11021,
#  'requir': 8316,
#  'central': 1849,
#  'repositori': 8299,
#  'ledger': 5783,
#  'maintain': 6069,
#  'updat': 10538,
#  'network': 6709,
#  'togeth': 10064,
#  'somewhat': 9195,
#  'similar': 8990,
#  'wikipedia': 10981,
#  'user': 10582,
#  'though': 9981,
#  'creat': 2520,
#  'privat': 7742,
#  'independ': 5112,
#  'ultim': 10323,
#  'detract': 2895,
#  'valu': 10624,
#  'individu': 5127,
#  'unit': 10446,
#  'known': 5646,
#  'ether': 3586,
#  'peopl': 7327,
#  'buy': 1663,
#  'interest': 5266,
#  'one': 6962,
#  'sign': 8973,
#  'major': 6071,
#  'bank': 1164,
#  'express': 3707,
#  'trade': 10137,
#  'money': 6471,
#  'transfer': 10158,
#  'faster': 3793,
#  'effici': 3336,
#  'tuesday': 10249,
#  'largest': 5707,
#  'gather': 4238,
#  'confer': 2294,
#  'tap': 9800,
#  'cut': 2630,
#  'hype': 4935,
#  'look': 5955,
#  'might': 6341,
#  'put': 7888,
#  'jpmorgan': 5513,
#  'instanc': 5223,
#  'specif': 9255,
#  'tool': 10085,
#  'allow': 702,
#  'intern': 5276,
#  'interact': 5259,
#  'michael': 6311,
#  'former': 4057,
#  'top': 10094,
#  'equiti': 3535,
#  'firm': 3912,
#  'fortress': 4067,
#  'invest': 5325,
#  'group': 4503,
#  'help': 4708,
#  'lead': 5757,
#  'sinc': 9005,
#  'left': 5786,
#  'fall': 3765,
#  'signific': 8978,
#  'purchas': 7872,
#  'januari': 5421,
#  'heard': 4683,
#  'financi': 3892,
#  'chatter': 1911,
#  'virtual': 10726,
#  'currenc': 2614,
#  'evolv': 3636,
#  'lot': 5971,
#  'establish': 3576,
#  'player': 7506,
#  'think': 9963,
#  'feel': 3833,
#  'two': 10295,
#  'three': 9989,
#  'month': 6488,
#  'least': 5775,
#  'get': 4303,
#  'valid': 10622,
#  'begin': 1245,
#  'soar': 9147,
#  'high': 4747,
#  '12': 51,
#  'around': 932,
#  'brought': 1575,
#  'exist': 3668,
#  'billion': 1323,
#  'time': 10028,
#  'significantli': 8979,
#  'outstand': 7089,
#  'week': 10898,
#  'invent': 5320,
#  'alt': 718,
#  'coin': 2155,
#  'tri': 10195,
#  'improv': 5060,
#  'none': 6792,
#  'follow': 4005,
#  'unlik': 10456,
#  '2009': 207,
#  'mysteri': 6610,
#  'creator': 2523,
#  'satoshi': 8640,
#  'nakamoto': 6624,
#  'transpar': 10170,
#  'fashion': 3791,
#  '21': 233,
#  'old': 6943,
#  'russian': 8565,
#  'canadian': 1728,
#  'vitalik': 10738,
#  'buterin': 1656,
#  'drop': 3210,
#  'waterloo': 10850,
#  'univers': 10448,
#  'ontario': 6975,
#  'basic': 1197,
#  'aim': 638,
#  'possibl': 7603,
#  'program': 7776,
#  'bind': 1327,
#  'agreement': 628,
#  'smart': 9106,
#  'bet': 1292,
#  'sport': 9305,
#  'game': 4211,
#  'final': 3889,
#  'score': 8693,
#  'came': 1714,
#  'mutual': 6602,
#  'agre': 627,
#  'upon': 10547,
#  'sourc': 9216,
#  'associ': 980,
#  'press': 7700,
#  'would': 11074,
#  'automat': 1062,
#  'win': 10996,
#  'parti': 7240,
#  'necessari': 6678,
#  'pay': 7281,
#  'power': 7625,
#  'need': 6682,
#  'process': 7757,
#  'sometim': 9194,
#  'describ': 2867,
#  'singl': 9012,
#  'share': 8866,
#  'run': 8553,
#  'resourc': 8344,
#  'parcel': 7223,
#  'paid': 7172,
#  'team': 9825,
#  'seven': 8834,
#  'co': 2110,
#  'founder': 4075,
#  'write': 11089,
#  'initi': 5185,
#  'descript': 2868,
#  'rais': 7992,
#  '18': 122,
#  'million': 6365,
#  '2014': 214,
#  'fund': 4172,
#  'foundat': 4074,
#  'support': 9644,
#  'succeed': 9579,
#  'attract': 1022,
#  'dedic': 2767,
#  'partli': 7247,
#  'hope': 4834,
#  'increas': 5102,
#  'succe': 9578,
#  '800': 410,
#  'node': 6782,
#  '400': 314,
#  'joseph': 5499,
#  'lubin': 5998,
#  'set': 8826,
#  'consensi': 2326,
#  'compani': 2230,
#  'base': 1188,
#  'brooklyn': 1572,
#  'hire': 4770,
#  '50': 339,
#  'build': 1610,
#  'applic': 878,
#  'includ': 5085,
#  'enabl': 3438,
#  'music': 6591,
#  'distribut': 3074,
#  'anoth': 821,
#  'new': 6720,
#  'kind': 5613,
#  'audit': 1032,
#  'offic': 6924,
#  'section': 8744,
#  'essenti': 3574,
#  'larg': 5705,
#  'room': 8504,
#  'messi': 6285,
#  'trademark': 10138,
#  'start': 9390,
#  'oper': 6998,
#  'white': 10952,
#  'board': 1411,
#  'wall': 10807,
#  'part': 7239,
#  'lie': 5842,
#  'thrown': 10000,
#  'deliv': 2809,
#  'fail': 3754,
#  'promis': 7791,
#  'especi': 3568,
#  'onlin': 6968,
#  'market': 6136,
#  'present': 7695,
#  'broad': 1559,
#  'stroke': 9505,
#  'vision': 10732,
#  'crystal': 2575,
#  'scienc': 8685,
#  'research': 8323,
#  'stanford': 9381,
#  'studi': 9520,
#  'crypto': 2571,
#  'realli': 8069,
#  'caught': 1816,
#  'sure': 9649,
#  'caution': 1820,
#  'probabl': 7749,
#  'safest': 8591,
#  'certainli': 1860,
#  'folk': 4004,
#  '10': 15,
#  'depend': 2847,
#  'actual': 534,
#  'alarm': 658,
#  'clock': 2075,
#  'wake': 10800,
#  'stream': 9487,
#  'broadcast': 1561,
#  'charg': 1893,
#  'per': 7331,
#  'second': 8737,
#  'current': 2615,
#  'btc': 1592,
#  'exchang': 3652,
#  'rate': 8026,
#  'button': 1662,
#  'costli': 2448,
#  'proposit': 7811,
#  'coffe': 2142,
#  'go': 4370,
#  'check': 1919,
#  'overnight': 7118,
#  'perform': 7345,
#  'bot': 1468,
#  'earn': 3284,
#  'trump': 10232,
#  'alloc': 700,
#  'main': 6063,
#  'chain': 1869,
#  'variou': 10643,
#  'nation': 6651,
#  'side': 8958,
#  'lucr': 6003,
#  '24': 247,
#  'return': 8379,
#  'reliabl': 8237,
#  'profit': 7772,
#  'ever': 3618,
#  'accord': 504,
#  'polit': 7563,
#  'predict': 7659,
#  'expect': 3674,
#  'latest': 5721,
#  'poll': 7565,
#  'number': 6862,
#  'highli': 4750,
#  'elect': 3367,
#  'ceo': 1854,
#  'resist': 8337,
#  'de': 2716,
#  'anonym': 819,
#  'spend': 9271,
#  'move': 6532,
#  'confidenti': 2298,
#  'layer': 5746,
#  'continu': 2375,
#  'erod': 3550,
#  'credibl': 2526,
#  'speech': 9263,
#  'ct': 2581,
#  'privaci': 7741,
#  'combat': 2195,
#  'sinist': 9015,
#  'ring': 8442,
#  'signatur': 8976,
#  'note': 6823,
#  'long': 5947,
#  'posit': 7601,
#  'memo': 6259,
#  'effect': 3334,
#  'govern': 4412,
#  'financ': 3891,
#  'complianc': 2252,
#  'british': 1556,
#  'corrupt': 2440,
#  'indic': 5120,
#  'light': 5853,
#  'britain': 1555,
#  'global': 4349,
#  'recoveri': 8130,
#  'great': 4462,
#  'debt': 2732,
#  'default': 2780,
#  '20': 196,
#  'happi': 4607,
#  'line': 5874,
#  'serv': 8819,
#  'autonom': 1066,
#  'info': 5162,
#  'agent': 619,
#  'ai': 636,
#  'provid': 7831,
#  'bounti': 1481,
#  'award': 1091,
#  'outfit': 7068,
#  'herd': 4721,
#  'mountain': 6527,
#  'goat': 4372,
#  'motion': 6517,
#  'sens': 8786,
#  'rig': 8437,
#  'alreadi': 715,
#  'repaid': 8279,
#  'figur': 3878,
#  'four': 4078,
#  'best': 1289,
#  'valuabl': 10625,
#  'artifici': 947,
#  'intellig': 5251,
#  'swiss': 9713,
#  'militari': 6356,
#  'robot': 8477,
#  'soon': 9201,
#  'enough': 3480,
#  'retir': 8368,
#  'citi': 2012,
#  'mar': 6116,
#  'excit': 3653,
#  'googl': 4397,
#  'center': 1845,
#  '360': 296,
#  'tour': 10116,
#  'youtub': 11162,
#  'video': 10700,
#  'give': 4331,
#  'unpreced': 10477,
#  'immers': 5021,
#  'insid': 5211,
#  'view': 10702,
#  'desktop': 2875,
#  'chrome': 1979,
#  'mous': 6528,
#  'trackpad': 10134,
#  'chang': 1880,
#  'play': 7503,
#  'app': 862,
#  'mobil': 6437,
#  'devic': 2905,
#  'angl': 802,
#  'cardboard': 1765,
#  'android': 794,
#  'io': 5334,
#  'come': 2200,
#  'load': 5919,
#  'icon': 4960,
#  'insert': 5210,
#  'phone': 7417,
#  'littl': 5910,
#  'background': 1118,
#  'ago': 626,
#  'us': 10571,
#  'advocaci': 590,
#  'rare': 8020,
#  'opportun': 7003,
#  'oregon': 7027,
#  'non': 6791,
#  'career': 1768,
#  'beyond': 1301,
#  'anyth': 843,
#  'imagin': 5009,
#  'blown': 1399,
#  'away': 1093,
#  'scale': 8656,
#  'incred': 5104,
#  'attent': 1018,
#  'amaz': 734,
#  'effort': 3337,
#  'extrem': 3723,
#  'green': 4470,
#  'addit': 551,
#  'proud': 7825,
#  'meet': 6239,
#  'brilliant': 1548,
#  'custom': 2626,
#  'want': 10819,
#  'experienc': 3682,
#  'enjoy': 3474,
#  'post': 7604,
#  'greg': 4475,
#  'wilson': 10994,
#  'head': 4663,
#  '2019': 219,
#  'reason': 8080,
#  'biggest': 1314,
#  'name': 6626,
#  'technolog': 9841,
#  'enter': 3490,
#  'space': 9225,
#  'evalu': 3606,
#  'linux': 5889,
#  'brightest': 1545,
#  'mind': 6372,
#  'hyperledg': 4938,
#  'umbrella': 10325,
#  'seek': 8754,
#  'incorpor': 5099,
#  'find': 3893,
#  'blockstream': 1387,
#  'rippl': 8447,
#  'digit': 2952,
#  'asset': 976,
#  'hold': 4792,
#  'other': 7052,
#  'order': 7021,
#  'contribut': 2387,
#  'code': 2130,
#  'john': 5483,
#  'offer': 6923,
#  'began': 1244,
#  'clear': 2048,
#  'disrupt': 3053,
#  'well': 10916,
#  'explor': 3697,
#  'announc': 814,
#  'decemb': 2742,
#  '17': 111,
#  '2015': 215,
#  'day': 2708,
#  'later': 5720,
#  '300': 277,
#  'request': 8315,
#  'join': 5486,
#  'open': 6985,
#  'histori': 4774,
#  '450': 326,
#  'inquiri': 5203,
#  'either': 3354,
#  'holi': 4796,
#  'mess': 6282,
#  'san': 8616,
#  'francisco': 4095,
#  'lighthous': 5855,
#  'partner': 7248,
#  'quest': 7933,
#  'understand': 10381,
#  'someth': 9193,
#  'import': 5049,
#  'know': 5642,
#  'got': 4405,
#  'rap': 8016,
#  '70': 392,
#  'back': 1113,
#  'cool': 2406,
#  'found': 4073,
#  'taxi': 9814,
#  'servic': 8824,
#  'explain': 3690,
#  'origin': 7034,
#  'crazi': 2517,
#  'guy': 4545,
#  '60': 372,
#  'wild': 10982,
#  'eye': 3726,
#  'revolutionari': 8399,
#  'although': 722,
#  'imag': 5005,
#  'quantum': 7921,
#  'teleport': 9864,
#  'semant': 8773,
#  'chip': 1956,
#  'count': 2458,
#  'among': 756,
#  'stuff': 9523,
#  'approach': 882,
#  'spirit': 9284,
#  'innov': 5200,
#  'method': 6297,
#  'often': 6932,
#  'mo': 6436,
#  '1990': 175,
#  'cite': 2011,
#  'java': 5429,
#  'today': 10060,
#  'pretti': 7708,
#  'young': 11157,
#  'dude': 3241,
#  'dollar': 3128,
#  'decis': 2750,
#  'xml': 11115,
#  'exampl': 3644,
#  'employe': 3431,
#  'consensu': 2327,
#  'algorithm': 675,
#  'entir': 3496,
#  '30': 276,
#  'planetari': 7493,
#  'gone': 4388,
#  'coupl': 2473,
#  'armi': 929,
#  'job': 5476,
#  'led': 5781,
#  'friend': 4132,
#  'contact': 2357,
#  'multin': 6570,
#  'consult': 2353,
#  'constantli': 2343,
#  'hey': 4733,
#  'let': 5820,
#  'everi': 3619,
#  'learn': 5771,
#  'acceler': 490,
#  'whole': 10960,
#  'went': 10918,
#  'environ': 3515,
#  'trust': 10236,
#  'end': 3450,
#  'era': 3538,
#  'manag': 6089,
#  'compens': 2238,
#  'risk': 8451,
#  'consum': 2354,
#  'institut': 5231,
#  'handl': 4590,
#  'complet': 2248,
#  'trustless': 10237,
#  'protocol': 7823,
#  'movement': 6533,
#  'everyth': 3625,
#  'fals': 3770,
#  'dichotomi': 2934,
#  'notion': 6830,
#  'garden': 4225,
#  'compar': 2233,
#  'wrong': 11092,
#  'analog': 772,
#  'apt': 889,
#  'perspect': 7371,
#  'permiss': 7358,
#  'iter': 5388,
#  'told': 10070,
#  'audienc': 1028,
#  'constrain': 2347,
#  'fabric': 3734,
#  'competit': 2240,
#  'huge': 4897,
#  'amount': 759,
#  'becom': 1234,
#  'econom': 3313,
#  'awar': 1090,
#  'mean': 6216,
#  'lost': 5970,
#  'caus': 1817,
#  'must': 6595,
#  'retool': 8369,
#  'fact': 3744,
#  'focus': 3998,
#  'cryptocurr': 2572,
#  'radic': 7976,
#  'banker': 1165,
#  'gonna': 4389,
#  'heck': 4695,
#  'ahead': 632,
#  'overstock': 7132,
#  't0': 9751,
#  'happen': 4606,
#  'plenti': 7517,
#  'commit': 2217,
#  'woken': 11030,
#  'mayb': 6198,
#  'wonder': 11034,
#  'aloud': 709,
#  'itun': 5391,
#  'napster': 6637,
#  'netflix': 6706,
#  'bittorr': 1350,
#  'product': 7764,
#  'watson': 10855,
#  'ecosystem': 3317,
#  'giant': 4310,
#  'everywher': 3626,
#  'els': 3390,
#  'investig': 5326,
#  'detail': 2886,
#  'oftentim': 6933,
#  'tinker': 10044,
#  'readi': 8055,
#  'rout': 8524,
#  'taken': 9776,
#  'par': 7206,
#  'ireland': 5355,
#  'energi': 3463,
#  'consumpt': 2356,
#  'mine': 6375,
#  'consortium': 2337,
#  'eventu': 3616,
#  'dictat': 2936,
#  'scare': 8665,
#  'deal': 2721,
#  'see': 8751,
#  'identifi': 4970,
#  'spread': 9313,
#  'arab': 894,
#  'spring': 9316,
#  'role': 8488,
#  'yet': 11148,
#  'structur': 9513,
#  'function': 4171,
#  'websit': 10891,
#  'albeit': 661,
#  'remain': 8251,
#  'protest': 7821,
#  'unruli': 10498,
#  'warn': 10832,
#  'movi': 6536,
#  'startup': 9393,
#  'equal': 3530,
#  'good': 4390,
#  'shot': 8929,
#  'restraint': 8354,
#  'keep': 5575,
#  'scope': 8692,
#  'simpl': 8993,
#  'oldest': 6945,
#  'organ': 7030,
#  'profession': 7768,
#  'kick': 5602,
#  'annual': 816,
#  'futur': 4192,
#  'tomorrow': 10077,
#  'schedul': 8673,
#  '000': 1,
#  'member': 6254,
#  '260': 260,
#  'countri': 2470,
#  'electr': 3368,
#  'electron': 3370,
#  'engin': 3468,
#  'ieee': 4980,
#  'profil': 7771,
#  'event': 3615,
#  'adopt': 571,
#  'commun': 2226,
#  'host': 4850,
#  'five': 3925,
#  'seminar': 8780,
#  '702': 395,
#  'colleg': 2176,
#  'oxford': 7148,
#  '2016': 216,
#  'fourth': 4081,
#  'speak': 9245,
#  'professor': 7769,
#  'wei': 10904,
#  'school': 8682,
#  'arizona': 923,
#  'state': 9398,
#  'talk': 9785,
#  'academ': 486,
#  'topic': 10095,
#  'shift': 8896,
#  'close': 2078,
#  'presenc': 7694,
#  'surpris': 9660,
#  'shape': 8863,
#  'stop': 9461,
#  'decentr': 2744,
#  'splash': 9288,
#  'wide': 10969,
#  'rang': 8009,
#  'news': 6729,
#  'relat': 8225,
#  'novemb': 6839,
#  'term': 9896,
#  'baa': 1109,
#  'sandbox': 8619,
#  'augur': 1036,
#  'slock': 9089,
#  'via': 10690,
#  'shutterstock': 8951,
#  'take': 9774,
#  'idea': 4964,
#  'embrac': 3407,
#  'fintech': 3905,
#  'pace': 7160,
#  'unabl': 10327,
#  'third': 9967,
#  'api': 856,
#  'access': 495,
#  'step': 9427,
#  'right': 8438,
#  'direct': 2976,
#  'input': 5202,
#  'competitor': 2241,
#  'true': 10229,
#  'bring': 1551,
#  'tabl': 9755,
#  'complementari': 2247,
#  'alli': 695,
#  'success': 9580,
#  'monetari': 6470,
#  'singapor': 9009,
#  'seem': 8756,
#  'read': 8052,
#  'price': 7717,
#  'analysi': 775,
#  '03': 5,
#  '28': 263,
#  'deni': 2832,
#  'sector': 8745,
#  'quit': 7952,
#  'door': 3148,
#  'differ': 2946,
#  'expert': 3685,
#  'threat': 9987,
#  'vocal': 10750,
#  'opposit': 7006,
#  'complement': 2246,
#  'infrastructur': 5167,
#  'rather': 8028,
#  'compet': 2239,
#  'combin': 2196,
#  'tradit': 10141,
#  'versatil': 10680,
#  'globe': 4352,
#  'entrepreneur': 3503,
#  'renown': 8270,
#  'outsid': 7086,
#  'proverbi': 7830,
#  'box': 1487,
#  'particularli': 7245,
#  'lend': 5804,
#  'peer': 7313,
#  'aspect': 968,
#  'concern': 2278,
#  'leg': 5788,
#  'counterpart': 2463,
#  'abl': 466,
#  'slow': 9095,
#  'simpli': 8996,
#  'unwil': 10530,
#  'behind': 1253,
#  'collabor': 2168,
#  'prefer': 7668,
#  'altern': 721,
#  'involv': 5333,
#  'swallow': 9688,
#  'pride': 7721,
#  'advanc': 577,
#  'featur': 3823,
#  'invalu': 5317,
#  'senior': 8785,
#  'regul': 8202,
#  'disruptor': 3054,
#  'versu': 10682,
#  'superior': 9630,
#  'despit': 2879,
#  'barrier': 1185,
#  'popular': 7586,
#  'avail': 1075,
#  'frictionless': 4128,
#  'regardless': 8190,
#  'previou': 7714,
#  'page': 7167,
#  'playbook': 7505,
#  'consid': 2332,
#  'issu': 5379,
#  'whether': 10941,
#  'human': 4904,
#  'usual': 10589,
#  'inventori': 5322,
#  'amazon': 736,
#  'warehous': 10826,
#  'mcdonald': 6207,
#  'place': 7485,
#  'tablet': 9757,
#  'instead': 5228,
#  'cashier': 1792,
#  'eat': 3299,
#  'lunch': 6014,
#  'toronto': 10101,
#  'core': 2424,
#  'contributor': 2388,
#  'peter': 7385,
#  'todd': 10061,
#  'ask': 965,
#  'street': 9489,
#  'point': 7545,
#  'dirti': 2982,
#  'secret': 8741,
#  'level': 5824,
#  'discuss': 3016,
#  'massiv': 6168,
#  'built': 1612,
#  'auditor': 1033,
#  'labor': 5675,
#  'be': 1217,
#  'sit': 9022,
#  'pore': 7588,
#  'thin': 9961,
#  'air': 639,
#  'disappear': 2988,
#  'legit': 5796,
#  'record': 8127,
#  'replac': 8288,
#  'believ': 1261,
#  'activ': 531,
#  'statu': 9407,
#  'quo': 7955,
#  'hard': 4615,
#  'fraud': 4103,
#  'toler': 10071,
#  'proper': 7805,
#  'speed': 9264,
#  'settlement': 8832,
#  'man': 6088,
#  'hour': 4862,
#  'difficult': 2948,
#  'correct': 2435,
#  'nearli': 6673,
#  'instantan': 5225,
#  'manner': 6106,
#  'ad': 539,
#  'lose': 5967,
#  'due': 3242,
#  'hacker': 4560,
#  'spoke': 9293,
#  'perceiv': 7332,
#  'advantag': 578,
#  'reli': 8236,
#  'admin': 561,
#  'key': 5590,
#  'strong': 9506,
#  'log': 5936,
#  'gave': 4242,
#  'type': 10298,
#  'cryptograph': 2573,
#  'tie': 10017,
#  'longtim': 5954,
#  'sort': 9208,
#  'receiv': 8101,
#  'natur': 6654,
#  'hear': 4682,
#  'oh': 6935,
#  'yeah': 11137,
#  'roughli': 8520,
#  'anyway': 845,
#  'trend': 10192,
#  'respond': 8347,
#  'rid': 8427,
#  'inde': 5109,
#  'comment': 2210,
#  'appear': 867,
#  'fit': 3923,
#  'paper': 7203,
#  'payment': 7286,
#  'proof': 7799,
#  'nick': 6752,
#  'hole': 4795,
#  'cost': 2446,
#  'kyle': 5670,
#  'freelanc': 4112,
#  'journalist': 5505,
#  '2011': 211,
#  'vice': 10695,
#  'motherboard': 6515,
#  'nasdaq': 6644,
#  ...}

# %% [markdown]
# #### The next step is to compute pair-wise similarities among all items/documents. We can use this similarity matrix to return the most similar items to a given item. Note, that the cosine_similarity function in sklearn.metrics.pairwise can natively work with sparse matrices

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sim_mat = cosine_similarity(art_mat2)
sim_mat.shape
# Out:
# (2211, 2211)

# %%
np.set_printoptions(linewidth=120, precision=2, edgeitems=10)

# %%
print(sim_mat)
# Out:
# [[1.   0.06 0.03 0.36 0.18 0.21 0.22 0.21 0.89 0.02 ... 0.06 0.06 0.05 0.01 0.04 0.02 0.03 0.07 0.14 0.02]
#  [0.06 1.   0.04 0.07 0.05 0.06 0.07 0.08 0.07 0.02 ... 0.06 0.05 0.02 0.   0.03 0.01 0.03 0.06 0.08 0.04]
#  [0.03 0.04 1.   0.03 0.04 0.02 0.03 0.03 0.02 0.06 ... 0.06 0.06 0.04 0.01 0.05 0.04 0.1  0.03 0.06 0.  ]
#  [0.36 0.07 0.03 1.   0.3  0.22 0.35 0.2  0.3  0.03 ... 0.1  0.06 0.07 0.01 0.08 0.04 0.03 0.05 0.17 0.02]
#  [0.18 0.05 0.04 0.3  1.   0.06 0.25 0.11 0.15 0.03 ... 0.07 0.04 0.02 0.03 0.03 0.02 0.04 0.12 0.12 0.02]
#  [0.21 0.06 0.02 0.22 0.06 1.   0.22 0.21 0.16 0.01 ... 0.11 0.04 0.05 0.01 0.02 0.02 0.02 0.04 0.21 0.02]
#  [0.22 0.07 0.03 0.35 0.25 0.22 1.   0.14 0.18 0.02 ... 0.11 0.06 0.06 0.   0.06 0.02 0.02 0.05 0.16 0.  ]
#  [0.21 0.08 0.03 0.2  0.11 0.21 0.14 1.   0.18 0.03 ... 0.06 0.08 0.05 0.02 0.04 0.02 0.04 0.03 0.07 0.02]
#  [0.89 0.07 0.02 0.3  0.15 0.16 0.18 0.18 1.   0.02 ... 0.06 0.05 0.04 0.01 0.03 0.02 0.03 0.06 0.12 0.01]
#  [0.02 0.02 0.06 0.03 0.03 0.01 0.02 0.03 0.02 1.   ... 0.03 0.06 0.08 0.   0.09 0.02 0.03 0.04 0.07 0.02]
#  ...
#  [0.06 0.06 0.06 0.1  0.07 0.11 0.11 0.06 0.06 0.03 ... 1.   0.11 0.06 0.07 0.05 0.06 0.05 0.05 0.13 0.04]
#  [0.06 0.05 0.06 0.06 0.04 0.04 0.06 0.08 0.05 0.06 ... 0.11 1.   0.09 0.03 0.08 0.06 0.09 0.05 0.1  0.02]
#  [0.05 0.02 0.04 0.07 0.02 0.05 0.06 0.05 0.04 0.08 ... 0.06 0.09 1.   0.01 0.25 0.04 0.12 0.04 0.09 0.02]
#  [0.01 0.   0.01 0.01 0.03 0.01 0.   0.02 0.01 0.   ... 0.07 0.03 0.01 1.   0.   0.02 0.01 0.03 0.02 0.03]
#  [0.04 0.03 0.05 0.08 0.03 0.02 0.06 0.04 0.03 0.09 ... 0.05 0.08 0.25 0.   1.   0.02 0.05 0.03 0.06 0.  ]
#  [0.02 0.01 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 ... 0.06 0.06 0.04 0.02 0.02 1.   0.04 0.04 0.05 0.02]
#  [0.03 0.03 0.1  0.03 0.04 0.02 0.02 0.04 0.03 0.03 ... 0.05 0.09 0.12 0.01 0.05 0.04 1.   0.05 0.07 0.01]
#  [0.07 0.06 0.03 0.05 0.12 0.04 0.05 0.03 0.06 0.04 ... 0.05 0.05 0.04 0.03 0.03 0.04 0.05 1.   0.1  0.1 ]
#  [0.14 0.08 0.06 0.17 0.12 0.21 0.16 0.07 0.12 0.07 ... 0.13 0.1  0.09 0.02 0.06 0.05 0.07 0.1  1.   0.05]
#  [0.02 0.04 0.   0.02 0.02 0.02 0.   0.02 0.01 0.02 ... 0.04 0.02 0.02 0.03 0.   0.02 0.01 0.1  0.05 1.  ]]

# %% [markdown]
# #### The following function takes a similarity matrix and a target item, and returns to k most similar items in the item database to the target item (it returns the indices of the k-nearest-neighbors along with their similarity values to the target item).

# %%
def content_based_sim(dataMat, simMatrix, item, k):
    sims = simMatrix[item,:]
    idx = np.argsort(sims)
    idx = idx[::-1]
    ### Need to remove the item itself since it has the highest similarity to itself
    idx = np.array([i for i in idx if i != item])
    neigh_idx = idx[:k]
    neigh_sims = sims[neigh_idx]
    return neigh_idx, neigh_sims

# %% [markdown]
# #### Let's look at a specific item (the article with index 249) and find the top 10 most similar items.

# %%
item = 249
articles.loc[item]['title']
# Out:
# 'Digital banking: Mondo hopes to become the Google or Facebook of the sector'

# %%
nidx, nsims = content_based_sim(art_mat2, sim_mat, item, 10)

# %%
print(nidx)
# Out:
# [ 754  239  247 2143 1482  261 1850  683  702 1758]

# %%
print(nsims)
# Out:
# [0.49 0.44 0.41 0.4  0.39 0.39 0.38 0.38 0.38 0.37]

# %%
pd.set_option('max_colwidth', 100)

# %% [markdown]
# #### And here are the top 10 recommendations based on the above target (query) item. It's clear from the titles that the recommeded items are very similar (in terms of content) to the target item.

# %%
articles.iloc[nidx]['title']
# Out:
# 754       The #digital upstarts offering app-only #banking for smartphone users #benchmark
# 239                                                    Building a digital-banking business
# 247                          Why Barclays Sees Banking's Future as an Information Business
# 2143                                   Mapping the Global NeoBank Landscape - Techfoliance
# 1482    Mobile-Only Challenger Banks Are Shaping the Future of Financial Services Industry
# 261                           App-only bank Atom just launched - here's what it looks like
# 1850                          Digital Tool as Strategic Enabler for Banking Transformation
# 683                                            A digital crack in banking's business model
# 702       Welcome to GoogleBank, Facebook Bank, Amazon Bank, and Apple Bank - Enrique Dans
# 1758                                   Blockchain Will Be Used By 15% of Big Banks By 2017
# Name: title, dtype: object

# %% [markdown]
# #### Observations about the content_based_sim function:
#
# <ul>
#     <li>
#         First thing to note is that this is a non-personalized form of recommendations. A user preference
#         profile is not being using to generated recommendation; only a query/target item is used. Below,
#         we will explore a more personalized form of content-based recommendation.
#     </li>
#     <li>
#         It should also be noted that the above function could, in fact, work with any item-item similarity
#         matrix. For example, the sim matrix could be based on a ratings matrix as in the case of item-based
#         collaborative filtering and does not need to be based on similarity of content-features. This
#         observation also points to the possibility that we can combine content-based and collaborative
#         filtering by using two independent similarity functions (a collaborative and a content-based one) to
#         create a hybrid recommender system (a good potential project idea).
#     </li>
#     <li>
#         Finally, it's important to point out that creating a separate similarity matrix offline, while
#         advantageous in terms of scalability, also has drawbacks. The sim matrix is generated based on
#         existing items in our item database. So, the content_based_sim function can only accept a target
#         item that is already represented in the database. This negates one of the key advantages of
#         content-based filtering which theoretically should allow a completely new item, represented using
#         the current feature space, should still be accepted as a target item, and the system should be
#         able to generate recommendations for that item. To allow for this, we would have to forego the
#         use of an offline similarity matrix and measure similarities between the target item and all items in
#         the databases during the recommendation generation time (i.e., within the content_based_sim function).
#     </li>
# </ul>

# %% [markdown]
# #### To be able to generate personalized recommendations, we need to first generate a user profile based on past preferences of the user. This could be done by collecting items the user has previous rated positively, or even just items they viewed, selected, purchased, etc. If there are both positive and negative ratings or ratings from a range of values, these ratings can be used as weights when creating an aggregate representation for the user's profile. In this case, the data provides information on users' various interactions with the items. For the purpose of this example, we are going to only consider articles that were "liked" by users. We'll combine all such articles for each user to create their profile as a feature vector over the set of features we already extracted earlier from documents.

# %%
interactions_df = pd.read_csv('http://facweb.cs.depaul.edu/mobasher/classes/csc577/data/users_interactions.csv')
interactions_df.head(3)
# Out:
#     timestamp eventType            contentId             personId  \
# 0  1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1  1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2  1465416190      VIEW   310515487419366995 -1130272294246983140
#
#              sessionId  \
# 0  1264196770339959068
# 1  3621737643587579081
# 2  2631864456530402479
#
#                                                                                              userAgent  \
# 0                                                                                                  NaN
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52...
# 2                                                                                                  NaN
#
#   userRegion userCountry
# 0        NaN         NaN
# 1         NY          US
# 2        NaN         NaN

# %%
liked_df = interactions_df[interactions_df["eventType"]=="LIKE"]

# %%
liked_df.head()
# Out:
#      timestamp eventType            contentId             personId  \
# 33  1465415756      LIKE -8142426490949346803  1908339160857512799
# 36  1465413867      LIKE   310515487419366995  3609194402293569455
# 40  1465413845      LIKE   310515487419366995   344280948527967603
# 43  1465413946      LIKE   310515487419366995 -8763398617720485024
# 56  1465413763      LIKE -1492913151930215984  3609194402293569455
#
#               sessionId userAgent userRegion userCountry
# 33  9121879357144259163       NaN        NaN         NaN
# 36  1143207167886864524       NaN        NaN         NaN
# 40 -3167637573980064150       NaN        NaN         NaN
# 43  1395789369402380392       NaN        NaN         NaN
# 56  1143207167886864524       NaN        NaN         NaN

# %% [markdown]
# #### To match these records with the shared articles, we only need the personId and contentId fields

# %%
liked_df = liked_df[["personId", "contentId"]]
liked_df.head()
# Out:
#                personId            contentId
# 33  1908339160857512799 -8142426490949346803
# 36  3609194402293569455   310515487419366995
# 40   344280948527967603   310515487419366995
# 43 -8763398617720485024   310515487419366995
# 56  3609194402293569455 -1492913151930215984

# %%
liked_df.shape
# Out:
# (5745, 2)

# %%
### No. of unique users in the data
len(liked_df["personId"].unique())
# Out:
# 788

# %%
### No. of unique items in the data
len(liked_df["contentId"].unique())
# Out:
# 1742

# %%
### Let's remind ourselves about what the articles dataframe looked like
articles.head()
# Out:
#              contentId  \
# 0 -4110354420726924665
# 1 -7292285110016212249
# 2 -6151852268067518688
# 3  2448026894306402386
# 4 -2826566343807132236
#
#                                                                      title  \
# 0  Ethereum, a Virtual Currency, Enables Transactions That Rival Bitcoin's
# 1       Bitcoin Future: When GBPcoin of Branson Wins Over USDcoin of Trump
# 2                                             Google Data Center 360° Tour
# 3            IBM Wants to "Evolve the Internet" With Blockchain Technology
# 4         IEEE to Talk Blockchain at Cloud Computing Oxford-Con - CoinDesk
#
#                                                                                                   text
# 0  All of this work is still very early. The first full public version of the Ethereum software was...
# 1  The alarm clock wakes me at 8:00 with stream of advert-free broadcasting, charged at one satoshi...
# 2  We're excited to share the Google Data Center 360° Tour - a YouTube 360° video that gives you an...
# 3  The Aite Group projects the blockchain market could be valued at $400 million by 2019. For that ...
# 4  One of the largest and oldest organizations for computing professionals will kick off its annual...

# %% [markdown]
# #### We can now do a join of these two tables (articles and liked_df dataframes)

# %%
ui_merge = pd.merge(liked_df, articles)
ui_merge.head()
# Out:
#               personId            contentId  \
# 0  3609194402293569455 -1492913151930215984
# 1  7774613525190730745 -1492913151930215984
# 2  7527226129639571966 -1492913151930215984
# 3 -1602833675167376798  3727587882617538492
# 4 -1602833675167376798  -692972306229904743
#
#                                             title  \
# 0         Chrome DevTools - Console API Reference
# 1         Chrome DevTools - Console API Reference
# 2         Chrome DevTools - Console API Reference
# 3  Bitcoin In The Time Of Negative Interest Rates
# 4    Blockchain won't kill banks: Bitcoin pioneer
#
#                                                                                                   text
# 0  The DevTools docs have moved! Read the latest version of this article and head over to the new h...
# 1  The DevTools docs have moved! Read the latest version of this article and head over to the new h...
# 2  The DevTools docs have moved! Read the latest version of this article and head over to the new h...
# 3  The Central Banks of Japan and Europe have imposed negative interest rates on deposits. Would th...
# 4  Blockchain - the technology that underpins the cryptocurrency bitcoin - is unlikely to kill bank...

# %% [markdown]
# #### Let's look at the articles liked by a specific user in the database

# %%
pid = -1602833675167376798
p = ui_merge[ui_merge["personId"]==pid]
p
# Out:
#                  personId            contentId  \
# 3    -1602833675167376798  3727587882617538492
# 4    -1602833675167376798  -692972306229904743
# 27   -1602833675167376798   -21036008762564671
# 90   -1602833675167376798  1929674614667189969
# 113  -1602833675167376798 -1654063646246197191
# ...                   ...                  ...
# 3352 -1602833675167376798  2760335717049716507
# 3381 -1602833675167376798  -746073086109727488
# 3405 -1602833675167376798  6831941111848480366
# 3409 -1602833675167376798  6244532954645766056
# 3423 -1602833675167376798  4866620033136147586
#
#                                                                                    title  \
# 3                                         Bitcoin In The Time Of Negative Interest Rates
# 4                                           Blockchain won't kill banks: Bitcoin pioneer
# 27                                            The sales secrets of high-growth companies
# 90    Diane Greene wants to put the enterprise front and center of Google Cloud strategy
# 113                                                                        Big IT Rising
# ...                                                                                  ...
# 3352                                  Razorfish, US digital revenues, drag down Publicis
# 3381                          How to get the most from your agency relationships in 2017
# 3405                             Amazon looking to buy Capital One? " Banking Technology
# 3409                       3 Big Blockchain Ideas MIT is Working on Right Now - CoinDesk
# 3423                     Siemens and General Electric gear up for the internet of things
#
#                                                                                                      text
# 3     The Central Banks of Japan and Europe have imposed negative interest rates on deposits. Would th...
# 4     Blockchain - the technology that underpins the cryptocurrency bitcoin - is unlikely to kill bank...
# 27    The authors of Sales Growth reveal five actions that distinguish sales organizations at fast-gro...
# 90    When Google bought bebop Technologies last fall for $348 million , it got more than a stealthy s...
# 113   Big IT rising An overview of Lean, Agile and DevOps New Ways of Working The lunch of big corpora...
# ...                                                                                                   ...
# 3352  It looked like a stunning strategy. After Publicis - one of the world's largest media and commun...
# 3381  Executives who know how to set up and manage agency relationships are best positioned to improve...
# 3405  Amazon is rumoured to be pondering the acquisition of Capital One. Banking Technology contacted ...
# 3409  When one of the world's most prestigious universities announces it will explore a controversial ...
# 3423  IT DOESN'T take long to walk from Siemens's old headquarters in Munich to its new one, inaugurat...
#
# [111 rows x 4 columns]

# %% [markdown]
# #### We can combine all the items in a given user's record to create the profile. This could be done by creating separate vectors for each item/document and then take the sum or the mean of the vectors. If the user has rating values associated with these items, they could be used to compute a weighted sum or mean. In this case, there are only unary ratings ("liked") for items and it is more convenient for first concatenate all documents belonging to the user, and then generate a feature vector for the combined document.

# %%
user_texts = pd.DataFrame([], columns=['personId', 'text'])
user_content = {} # a dictionary to keep track of article ids for each user
for pid in set(ui_merge["personId"]):
    p = ui_merge[ui_merge["personId"]==pid]
    all_text = ' '.join(p["text"])
    user_content[pid] = [a for a in p["contentId"]]
    row = pd.DataFrame([[pid, all_text]], columns=['personId', 'text'])
    user_texts = user_texts.append(row, ignore_index=True)

# %%
user_texts.head()
# Out:
#                personId  \
# 0  -6174073684310263806
# 1   3813842765808990208
# 2   4142810830429822977
# 3  -8694104221113176052
# 4  -1678759546322702318
#
#                                                                                                   text
# 0  Here are the SDKs Top Mobile Apps Use We are working on a free community resource for mobile app...
# 1  Editor's note: this is the seventh post in a series of in-depth posts on what's new in Kubernete...
# 2  Bottom line: Machine learning is providing the needed algorithms, applications, and frameworks t...
# 3  Big IT rising An overview of Lean, Agile and DevOps New Ways of Working The lunch of big corpora...
# 4  2015 has been heralded as the year the Internet of Things finally takes hold, but while we wait ...

# %%
user_content[-1602833675167376798]
# Out:
# [3727587882617538492,
#  -692972306229904743,
#  -21036008762564671,
#  1929674614667189969,
#  -1654063646246197191,
#  -5170198873410718233,
#  8265190708606665292,
#  6437568358552101410,
#  -862645085190435621,
#  -2871288807409592,
#  -3363563881552061188,
#  2857117417189640073,
#  -7681408188643141872,
#  3149164017776669829,
#  2916072977192006313,
#  4814419120794996930,
#  -662806181534790446,
#  -3750879736572068916,
#  2072448887839540892,
#  5238119115012015307,
#  -5410531116380081703,
#  643905832258297060,
#  -1088742830039453732,
#  6754313450809254838,
#  7229629480273331039,
#  -205193648629294862,
#  7124632953201847659,
#  1544550983918141657,
#  5152069678055228801,
#  8118799783881928573,
#  4774970687540378081,
#  2885511262558254418,
#  4139191914110236238,
#  9032993320407723266,
#  1459131257418324496,
#  4419562057180692966,
#  5468598741732935699,
#  -2539915991213675511,
#  -9055044275358686874,
#  6152652267138213180,
#  -667193404227875686,
#  3075564241645350154,
#  -5912792039759735631,
#  -8312968399134741370,
#  -4320251915347436672,
#  -1101832997669013246,
#  2947843229055216994,
#  8559816910657872807,
#  -8700857105739861338,
#  2727743992157210358,
#  5533752987392101383,
#  -8369610219380465981,
#  -4770861947600256785,
#  1356221992133852808,
#  607684800821303652,
#  -8282357075607822317,
#  -3095494965842381869,
#  -8208801367848627943,
#  -7990179956144740367,
#  1436883058900979473,
#  5293701842202310496,
#  -8187220755213888616,
#  -4414039190127558142,
#  -9128741757954228992,
#  -7484960773951920439,
#  4102576381061107965,
#  3455160158461205368,
#  -7162567255723313045,
#  549631724393582960,
#  4125609302375934769,
#  4039031731864440026,
#  -3395906801262755897,
#  3273084325487543386,
#  -2630716662499331227,
#  -1443900796086927361,
#  6881796783400625893,
#  1266958185239582088,
#  4785499183287168509,
#  7510090557616166004,
#  -3645539449929727083,
#  -1676378465482420452,
#  -5154395767417065070,
#  834896074125772354,
#  3715130189384008388,
#  -2896441888220202695,
#  -2890958311805113955,
#  3058137260516373249,
#  7506614456429888492,
#  -6579094253358169934,
#  -4893195573827770029,
#  -4483059513836093676,
#  -3060116862184714437,
#  -9086955082453789880,
#  -3269885695260066314,
#  -4293262855938209141,
#  -4925213312961842798,
#  6222001809679591440,
#  4671890082953295903,
#  -3951274083288934897,
#  -2123288010168989418,
#  -885453047081832598,
#  5930806521893160184,
#  2952636544547704346,
#  -3900870368325485697,
#  -8392586470872505716,
#  -8900113512825364282,
#  2760335717049716507,
#  -746073086109727488,
#  6831941111848480366,
#  6244532954645766056,
#  4866620033136147586]

# %% [markdown]
# #### Now we can use our vectorizer that was trained on the original document set to transform the new profile documents.

# %%
user_profiles = vectorizer2.transform(user_texts['text'])

# %%
user_profiles
# Out:
# <564x11194 sparse matrix of type '<class 'numpy.float64'>'
# 	with 475164 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### Each element/row of "user_profiles" represents the feature vector for one user (essentially feature representation of the concatenated documents liked by the user. Below are the first couple of uses (in sparse matrix format) with user index, feature index, and TFxIDF weights.

# %%
print(user_profiles[0:2])
# Out:
#   (0, 11162)	4.2828117548456275
#   (0, 11148)	4.865112157871928
#   (0, 11138)	5.164729266241387
#   (0, 11099)	40.67896423322242
#   (0, 11090)	4.558517636250693
#   (0, 11081)	4.259001106151909
#   (0, 11074)	10.621083342256632
#   (0, 11063)	4.259001106151909
#   (0, 11047)	23.103114967714923
#   (0, 11021)	4.066848228449644
#   (0, 11020)	7.213629128124869
#   (0, 10952)	3.8733386253399242
#   (0, 10950)	5.993602161540015
#   (0, 10941)	4.9700925231147215
#   (0, 10916)	1.7160105450030172
#   (0, 10891)	2.86684162557962
#   (0, 10876)	4.838771231492437
#   (0, 10861)	3.0159330884942275
#   (0, 10858)	7.092214450208125
#   (0, 10847)	35.96161296924009
#   (0, 10844)	12.502813037983637
#   (0, 10819)	1.7031427203916243
#   (0, 10804)	3.760009940032921
#   (0, 10751)	13.81978578682834
#   (0, 10736)	9.588962480129588
#   :	:
#   (1, 282)	4.7698267299179
#   (1, 276)	9.222093746854766
#   (1, 266)	4.712668316077951
#   (1, 263)	4.574517977597134
#   (1, 261)	4.809832064531599
#   (1, 259)	4.712668316077951
#   (1, 252)	7.19141377748329
#   (1, 247)	3.760009940032921
#   (1, 244)	4.641209352095807
#   (1, 240)	8.795174538876111
#   (1, 233)	8.664409020350408
#   (1, 215)	3.160388817483799
#   (1, 214)	3.388446383600438
#   (1, 198)	4.750408644060798
#   (1, 196)	44.09401469793073
#   (1, 131)	4.319625727968344
#   (1, 122)	7.966306982694261
#   (1, 111)	4.096482176654134
#   (1, 99)	3.796377584203796
#   (1, 89)	3.208590919301677
#   (1, 77)	3.9831534913471307
#   (1, 64)	7.730740911381495
#   (1, 51)	6.643510018203532
#   (1, 39)	3.6202479976577626
#   (1, 15)	14.493925608800165

# %% [markdown]
# #### Now we are ready to generate some presonalized recommendations. The following function takes a user (feature vector for a target user's profile) and returns the indices of the top k most similar items to the user's profile. The function also has an input argument "rated_items_indicies" which is an array of indices of items in the user profile (in this case, these are indices in the "articles" dataframe corresponding to articles that the user has previously liked).

# %%
def content_based_recommend(dataMat, user, rated_items_indicies, k):
    from sklearn.metrics.pairwise import cosine_similarity
    sims = cosine_similarity(dataMat, user)
    sims = sims.flatten() # cosine_similarity returns a nx1 array; flatten it into a 1d numpy array
    idx = np.argsort(sims)
    # Make sure we don't add items that are already rated by the user
    idx = np.array([i for i in idx if not (i in rated_items_indicies)])
    idx = idx[::-1]
    neigh_idx = idx[:k]
    neigh_sims = sims[neigh_idx]
    return neigh_idx, neigh_sims

# %% [markdown]
# #### Let's test this in a specific user (user with index 20)

# %%
u = 20
user = user_profiles[u]
pid = user_texts.iloc[u]["personId"]
rated_items = articles[articles["contentId"].isin(user_content[pid])]

# %%
rated_items_idx = np.array(rated_items.index)
rated_items_idx
# Out:
# array([1368, 1378, 1431, 1467, 1814], dtype=int64)

# %%
n_index, n_sims = content_based_recommend(art_mat2, user, rated_items_idx, 5)

# %%
n_index
# Out:
# array([ 631, 1043, 2157,  278, 1125], dtype=int64)

# %% [markdown]
# #### Here are the articles previosuly "liked" by this user:

# %%
rated_items["title"]
# Out:
# 1368                                                   Promoting gender equality through emoji �� ��
# 1378                  Neural networks are inadvertently learning our language's hidden gender biases
# 1431    Glamour Exclusive: President Obama On Feminism and The World He Wants to Leave His Daughters
# 1467                                         The Genderbread Person v3 | It's Pronounced Metrosexual
# 1814                                                               Introducing Ask a Female Engineer
# Name: title, dtype: object

# %% [markdown]
# #### And here are the top 5 recommendations based on the user's profile:

# %%
recs = articles.iloc[n_index]
recs
# Out:
#                 contentId  \
# 631    764116021156146784
# 1043   -96719740408441346
# 2157  6463551093741815202
# 278   2927476152522512441
# 1125 -8412113620940365599
#
#                                                                                                     title  \
# 631   If you think women in tech is just a pipeline problem, you haven't been paying attention - Tech ...
# 1043                                                      In war for talent, 'brogrammers' will be losers
# 2157                                          Little girls doubt that women can be brilliant, study shows
# 278                                                              Equal Pay Day in the spotlight this year
# 1125                                                      The best-and worst-places to be a working woman
#
#                                                                                                      text
# 631   If you think women in tech is just a pipeline problem, you haven't been paying attention Accordi...
# 1043  Start-ups are fighting a war for talent in Silicon Valley, and the companies that actively welco...
# 2157  WASHINGTON - Can women be brilliant? Little girls are not so sure. A study published Thursday in...
# 278   As if you hadn't heard - and surely, you have heard - women earn less money than men. The oft-ci...
# 1125  The best-and worst-places to be a working woman by The Data Team TO MARK the United Nations ' In...

# %% [markdown]
# #### It's clear that the recommender is finding items that are quite similar to user's past interests.

# %% [markdown]
# #### Note that content_based_recommender function does not require that the target user should be an existing user in the database. Indeed, a new user who has rated some of the articles can be represented as a feature vector over the existing feature space and passed to this function. So, it has the "liveness" property in the sense that it can generate out-of-sample recommendations.

# %% [markdown]
# #### A note on evaluation:
# <p>While it's possible to do rating prediction with content-based recommenders (for example in a manner similar to item-based collaborative filtering method), it is more common to view these systems as "top-n recommender systems". In other words, the main goal of the system is to return a ranked list of n recommendations for a given target user. There are a number of evaluation metrics such as precision, recall, hit ratio, and normalized discounted cumulative gain (NDCG) that can be used to evaluate the quality of the ranked list.</p>
# <p>Typically, a portion of the items in each user profile in the test set is set aside for evaluation. The remaining part of the user profile is used to generate a recommendation list of size n. For example, precison@k for each test user can be computed by determining the ratio of top k recommended items that are present in the set aside portion of the profile. Average precision@k is then computed based on all test users. Recall, on the other hand can be computed based on the ratio of the set-aside items that are covered by top-k recommendation.</p>
# <p>You can find a detailed discussion of evaluation metrics for recommendation, including the evaluation of ranked lists in Chapter 7 (Section 7.5) of the Aggarwal book: "Recommender Systems: A Texbook".</p>
